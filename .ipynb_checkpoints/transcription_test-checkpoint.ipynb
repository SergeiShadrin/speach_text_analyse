# %%
import sys
import os
from pathlib import Path
import logging
from dotenv import load_dotenv

project_root = os.getcwd() 
if project_root not in sys.path:
    sys.path.append(project_root)

load_dotenv(override=True)

print(f"Project Root: {project_root}")
if os.getenv("REPLICATE_API_TOKEN"):
    print("✅ API Token loaded.")
else:
    print("❌ Warning: API Token NOT found.")

logging.basicConfig(
    level=logging.INFO, 
    format='%(asctime)s - %(levelname)s - %(message)s',
    force=True 
)

from app.services import TranscriptionService
# Out:
# Project Root: /Users/sergeishadrin/Dev/Work/audio_transcription
# ✅ API Token loaded.

# %%
service = TranscriptionService()
service.run()
# Out:
# 2026-01-02 21:10:46,413 - INFO - Found 7 files to process.
# 2026-01-02 21:10:46,414 - INFO - 🚀 Starting pipeline for: matin_3
# 2026-01-02 21:10:46,415 - INFO - Step 1: Extracting audio...
# 2026-01-02 21:10:59,542 - INFO -    -> Audio saved to: data/input/audio/matin_3.wav
# 2026-01-02 21:10:59,543 - INFO - Step 2: Splitting audio...
# 2026-01-02 21:11:00,118 - INFO -    -> Created 3 audio chunks.
# 2026-01-02 21:11:00,119 - INFO - Step 3: Transcribing chunks...
# 2026-01-02 21:11:00,120 - INFO -    -> Transcribing part 1/3...
# 2026-01-02 21:11:27,503 - INFO - HTTP Request: POST https://api.replicate.com/v1/files "HTTP/1.1 201 Created"
# 2026-01-02 21:12:14,102 - INFO - HTTP Request: POST https://api.replicate.com/v1/predictions "HTTP/1.1 201 Created"
# 2026-01-02 21:12:14,236 - INFO - HTTP Request: GET https://api.replicate.com/v1/models/victor-upmeet/whisperx/versions/84d2ad2d6194fe98a17d2b60bef1c7f910c46b2f6fd38996ca457afd9c8abfcb "HTTP/1.1 200 OK"
# 2026-01-02 21:12:14,249 - INFO -    -> Transcribing part 2/3...
# 2026-01-02 21:12:39,441 - INFO - HTTP Request: POST https://api.replicate.com/v1/files "HTTP/1.1 201 Created"
# 2026-01-02 21:13:27,207 - INFO - HTTP Request: POST https://api.replicate.com/v1/predictions "HTTP/1.1 201 Created"
# 2026-01-02 21:13:27,337 - INFO - HTTP Request: GET https://api.replicate.com/v1/models/victor-upmeet/whisperx/versions/84d2ad2d6194fe98a17d2b60bef1c7f910c46b2f6fd38996ca457afd9c8abfcb "HTTP/1.1 200 OK"
# 2026-01-02 21:13:27,346 - INFO -    -> Transcribing part 3/3...
# 2026-01-02 21:13:30,685 - INFO - HTTP Request: POST https://api.replicate.com/v1/files "HTTP/1.1 201 Created"
# 2026-01-02 21:13:39,599 - INFO - HTTP Request: POST https://api.replicate.com/v1/predictions "HTTP/1.1 201 Created"
# 2026-01-02 21:13:39,729 - INFO - HTTP Request: GET https://api.replicate.com/v1/models/victor-upmeet/whisperx/versions/84d2ad2d6194fe98a17d2b60bef1c7f910c46b2f6fd38996ca457afd9c8abfcb "HTTP/1.1 200 OK"
# 2026-01-02 21:13:39,809 - INFO - Step 4: Normalizing and merging text...
# 2026-01-02 21:13:39,812 - INFO - Merging files from: data/_temp/matin_3/text_chunks
# 2026-01-02 21:13:39,816 - INFO - Starting normalization of 2 chunks...
# 2026-01-02 21:13:39,817 - INFO - Processing chunk 1/2...
# 2026-01-02 21:13:39,829 - INFO - AFC is enabled with max remote calls: 10.
# 2026-01-02 21:15:26,503 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-3-flash-preview:generateContent "HTTP/1.1 200 OK"
# 2026-01-02 21:15:26,525 - INFO - Processing chunk 2/2...
# 2026-01-02 21:15:26,526 - INFO - AFC is enabled with max remote calls: 10.
# 2026-01-02 21:15:49,336 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-3-flash-preview:generateContent "HTTP/1.1 200 OK"
# 2026-01-02 21:15:49,349 - INFO - ✅ Pipeline Complete! Result saved to: data/output/transcriptions/transcription_matin_3.txt
# 2026-01-02 21:15:49,404 - INFO - Deleted temp audio: data/input/audio/matin_3.wav
# 2026-01-02 21:15:49,469 - INFO - Deleted temp directory: data/_temp/matin_3
# 2026-01-02 21:15:49,471 - INFO - Moved matin_3.mp4 to archives.
# 2026-01-02 21:15:49,472 - INFO - 🚀 Starting pipeline for: aprem_01
# 2026-01-02 21:15:49,473 - INFO - Step 1: Extracting audio...
# 2026-01-02 21:16:04,189 - INFO -    -> Audio saved to: data/input/audio/aprem_01.wav
# 2026-01-02 21:16:04,192 - INFO - Step 2: Splitting audio...
# 2026-01-02 21:16:04,621 - INFO -    -> Created 3 audio chunks.
# 2026-01-02 21:16:04,622 - INFO - Step 3: Transcribing chunks...
# 2026-01-02 21:16:04,622 - INFO -    -> Transcribing part 1/3...
# 2026-01-02 21:16:31,935 - INFO - HTTP Request: POST https://api.replicate.com/v1/files "HTTP/1.1 201 Created"
# 2026-01-02 21:17:21,150 - INFO - HTTP Request: POST https://api.replicate.com/v1/predictions "HTTP/1.1 201 Created"
# 2026-01-02 21:17:21,300 - INFO - HTTP Request: GET https://api.replicate.com/v1/models/victor-upmeet/whisperx/versions/84d2ad2d6194fe98a17d2b60bef1c7f910c46b2f6fd38996ca457afd9c8abfcb "HTTP/1.1 200 OK"
# 2026-01-02 21:17:21,311 - INFO -    -> Transcribing part 2/3...
# 2026-01-02 21:17:46,176 - INFO - HTTP Request: POST https://api.replicate.com/v1/files "HTTP/1.1 201 Created"
# 2026-01-02 21:18:36,951 - INFO - HTTP Request: POST https://api.replicate.com/v1/predictions "HTTP/1.1 201 Created"
# 2026-01-02 21:18:37,087 - INFO - HTTP Request: GET https://api.replicate.com/v1/models/victor-upmeet/whisperx/versions/84d2ad2d6194fe98a17d2b60bef1c7f910c46b2f6fd38996ca457afd9c8abfcb "HTTP/1.1 200 OK"
# 2026-01-02 21:18:37,102 - INFO -    -> Transcribing part 3/3...
