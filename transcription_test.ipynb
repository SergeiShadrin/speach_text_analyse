# %%
import sys
import os
from pathlib import Path
import logging
from dotenv import load_dotenv

project_root = os.getcwd() 
if project_root not in sys.path:
    sys.path.append(project_root)

load_dotenv(override=True)

print(f"Project Root: {project_root}")
if os.getenv("REPLICATE_API_TOKEN"):
    print("✅ API Token loaded.")
else:
    print("❌ Warning: API Token NOT found.")

logging.basicConfig(
    level=logging.INFO, 
    format='%(asctime)s - %(levelname)s - %(message)s',
    force=True 
)

from app.services import TranscriptionService
# Out:
# Project Root: /Users/sergeishadrin/Dev/Work/audio_transcription
# ✅ API Token loaded.

# %%
service = TranscriptionService()
service.run()
# Out:
# 2026-01-02 21:57:44,495 - INFO - Found 5 files to process.
# 2026-01-02 21:57:44,496 - INFO - 🚀 Starting pipeline for: aprem_03
# 2026-01-02 21:57:44,497 - INFO - Step 1: Extracting audio...
# 2026-01-02 21:57:45,504 - INFO -    -> Audio saved to: data/input/audio/aprem_03.wav
# 2026-01-02 21:57:45,504 - INFO - Step 2: Splitting audio...
# 2026-01-02 21:57:45,576 - INFO -    -> Created 1 audio chunks.
# 2026-01-02 21:57:45,577 - INFO - Step 3: Transcribing chunks...
# 2026-01-02 21:57:45,578 - INFO -    -> Transcribing part 1/1...
# 2026-01-02 21:57:51,118 - INFO - HTTP Request: POST https://api.replicate.com/v1/files "HTTP/1.1 201 Created"
# 2026-01-02 21:58:11,599 - INFO - HTTP Request: POST https://api.replicate.com/v1/predictions "HTTP/1.1 201 Created"
# 2026-01-02 21:58:11,732 - INFO - HTTP Request: GET https://api.replicate.com/v1/models/victor-upmeet/whisperx/versions/84d2ad2d6194fe98a17d2b60bef1c7f910c46b2f6fd38996ca457afd9c8abfcb "HTTP/1.1 200 OK"
# 2026-01-02 21:58:11,739 - INFO - Step 4: Normalizing and merging text...
# 2026-01-02 21:58:11,740 - INFO - Merging files from: data/_temp/aprem_03/text_chunks
# 2026-01-02 21:58:11,742 - INFO - Starting normalization of 1 chunks...
# 2026-01-02 21:58:11,742 - INFO - Processing chunk 1/1...
# 2026-01-02 21:58:11,744 - INFO - AFC is enabled with max remote calls: 10.
# 2026-01-02 21:58:49,900 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-3-flash-preview:generateContent "HTTP/1.1 200 OK"
# 2026-01-02 21:58:49,919 - INFO - ✅ Pipeline Complete! Result saved to: data/output/transcriptions/transcription_aprem_03.txt
# 2026-01-02 21:58:49,924 - INFO - Deleted temp audio: data/input/audio/aprem_03.wav
# 2026-01-02 21:58:49,927 - INFO - Deleted temp directory: data/_temp/aprem_03
# 2026-01-02 21:58:49,928 - INFO - Moved aprem_03.mp4 to archives.
# 2026-01-02 21:58:49,930 - INFO - 🚀 Starting pipeline for: aprem_02
# 2026-01-02 21:58:49,930 - INFO - Step 1: Extracting audio...
# 2026-01-02 21:59:03,893 - INFO -    -> Audio saved to: data/input/audio/aprem_02.wav
# 2026-01-02 21:59:03,895 - INFO - Step 2: Splitting audio...
# 2026-01-02 21:59:04,473 - INFO -    -> Created 3 audio chunks.
# 2026-01-02 21:59:04,474 - INFO - Step 3: Transcribing chunks...
# 2026-01-02 21:59:04,475 - INFO -    -> Transcribing part 1/3...
# 2026-01-02 21:59:24,411 - INFO - HTTP Request: POST https://api.replicate.com/v1/files "HTTP/1.1 201 Created"
# 2026-01-02 21:59:54,641 - INFO - HTTP Request: POST https://api.replicate.com/v1/predictions "HTTP/1.1 201 Created"
# 2026-01-02 21:59:54,764 - INFO - HTTP Request: GET https://api.replicate.com/v1/models/victor-upmeet/whisperx/versions/84d2ad2d6194fe98a17d2b60bef1c7f910c46b2f6fd38996ca457afd9c8abfcb "HTTP/1.1 200 OK"
# 2026-01-02 21:59:54,843 - ERROR - ❌ Failed to process aprem_02.mp4: 'NoneType' object has no attribute 'to'
# Traceback (most recent call last):
#   File "/Users/sergeishadrin/Dev/Work/audio_transcription/app/services.py", line 201, in run
#     self.process_file(
#   File "/Users/sergeishadrin/Dev/Work/audio_transcription/app/services.py", line 130, in process_file
#     transcription_chunk = self.transcriber.transcribe(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sergeishadrin/Dev/Work/audio_transcription/app/models/transcriber/replicate_transcriber.py", line 98, in transcribe
#     output = self.client.run(
#              ^^^^^^^^^^^^^^^^
#   File "/Users/sergeishadrin/Dev/Work/audio_transcription/venv/lib/python3.12/site-packages/replicate/client.py", line 175, in run
#     return run(self, ref, input, use_file_output=use_file_output, **params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sergeishadrin/Dev/Work/audio_transcription/venv/lib/python3.12/site-packages/replicate/run.py", line 81, in run
#     raise ModelError(prediction)
# replicate.exceptions.ModelError: 'NoneType' object has no attribute 'to'
# 2026-01-02 21:59:54,852 - INFO - 🚀 Starting pipeline for: matin_01.mp4 21-27-52-217
# 2026-01-02 21:59:54,853 - INFO - Step 1: Extracting audio...
# 2026-01-02 21:59:54,974 - ERROR - ❌ Failed to process matin_01.mp4 21-27-52-217.mp4: Conversion failed for data/input/matin_01.mp4 21-27-52-217.mp4: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x128f04080] moov atom not found
# [in#0 @ 0x600002528000] Error opening input: Invalid data found when processing input
# Error opening input file data/input/matin_01.mp4 21-27-52-217.mp4.
# Error opening input files: Invalid data found when processing input
# Traceback (most recent call last):
#   File "/Users/sergeishadrin/Dev/Work/audio_transcription/app/models/transcriber/media_converter.py", line 48, in extract_audio
#     subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#   File "/opt/anaconda3/lib/python3.12/subprocess.py", line 571, in run
#     raise CalledProcessError(retcode, process.args,
# subprocess.CalledProcessError: Command '['ffmpeg', '-i', 'data/input/matin_01.mp4 21-27-52-217.mp4', '-vn', '-acodec', 'pcm_s16le', '-ar', '16000', '-ac', '1', 'data/input/audio/matin_01.mp4 21-27-52-217.wav', '-y', '-loglevel', 'error']' returned non-zero exit status 183.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sergeishadrin/Dev/Work/audio_transcription/app/services.py", line 201, in run
#     self.process_file(
#   File "/Users/sergeishadrin/Dev/Work/audio_transcription/app/services.py", line 103, in process_file
#     wav_path = self.converter.extract_audio(str(input_file_path))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sergeishadrin/Dev/Work/audio_transcription/app/models/transcriber/media_converter.py", line 56, in extract_audio
#     raise RuntimeError(f"Conversion failed for {input_path}: {error_message}")
# RuntimeError: Conversion failed for data/input/matin_01.mp4 21-27-52-217.mp4: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x128f04080] moov atom not found
# [in#0 @ 0x600002528000] Error opening input: Invalid data found when processing input
# Error opening input file data/input/matin_01.mp4 21-27-52-217.mp4.
# Error opening input files: Invalid data found when processing input
#
# 2026-01-02 21:59:54,979 - INFO - 🚀 Starting pipeline for: matin_02.mp4 21-27-52-224
# 2026-01-02 21:59:54,979 - INFO - Step 1: Extracting audio...
# 2026-01-02 21:59:55,014 - ERROR - ❌ Failed to process matin_02.mp4 21-27-52-224.mp4: Conversion failed for data/input/matin_02.mp4 21-27-52-224.mp4: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x157f06f70] moov atom not found
# [in#0 @ 0x600002048700] Error opening input: Invalid data found when processing input
# Error opening input file data/input/matin_02.mp4 21-27-52-224.mp4.
# Error opening input files: Invalid data found when processing input
# Traceback (most recent call last):
#   File "/Users/sergeishadrin/Dev/Work/audio_transcription/app/models/transcriber/media_converter.py", line 48, in extract_audio
#     subprocess.run(command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#   File "/opt/anaconda3/lib/python3.12/subprocess.py", line 571, in run
#     raise CalledProcessError(retcode, process.args,
# subprocess.CalledProcessError: Command '['ffmpeg', '-i', 'data/input/matin_02.mp4 21-27-52-224.mp4', '-vn', '-acodec', 'pcm_s16le', '-ar', '16000', '-ac', '1', 'data/input/audio/matin_02.mp4 21-27-52-224.wav', '-y', '-loglevel', 'error']' returned non-zero exit status 183.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sergeishadrin/Dev/Work/audio_transcription/app/services.py", line 201, in run
#     self.process_file(
#   File "/Users/sergeishadrin/Dev/Work/audio_transcription/app/services.py", line 103, in process_file
#     wav_path = self.converter.extract_audio(str(input_file_path))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sergeishadrin/Dev/Work/audio_transcription/app/models/transcriber/media_converter.py", line 56, in extract_audio
#     raise RuntimeError(f"Conversion failed for {input_path}: {error_message}")
# RuntimeError: Conversion failed for data/input/matin_02.mp4 21-27-52-224.mp4: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x157f06f70] moov atom not found
# [in#0 @ 0x600002048700] Error opening input: Invalid data found when processing input
# Error opening input file data/input/matin_02.mp4 21-27-52-224.mp4.
# Error opening input files: Invalid data found when processing input
