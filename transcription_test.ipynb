# %%
import sys
import os
from pathlib import Path
import logging
from dotenv import load_dotenv

project_root = os.getcwd() 
if project_root not in sys.path:
    sys.path.append(project_root)

load_dotenv(override=True)

print(f"Project Root: {project_root}")
if os.getenv("REPLICATE_API_TOKEN"):
    print("✅ API Token loaded.")
else:
    print("❌ Warning: API Token NOT found.")

logging.basicConfig(
    level=logging.INFO, 
    format='%(asctime)s - %(levelname)s - %(message)s',
    force=True 
)

from app.services import TranscriptionService
# Out:
# Project Root: /Users/sergeishadrin/Dev/Work/audio_transcription
# ✅ API Token loaded.

# %%
service = TranscriptionService()
service.save_to_db_existing_transcriptions("/Users/sergeishadrin/Dev/Work/audio_transcription/data/output/transcriptions")
# Out:
# 2026-01-08 17:05:09,425 - INFO - Imported: transcription_aprem_01.txt
# 2026-01-08 17:05:09,430 - INFO - Imported: transcription_aprem_03.txt
# 2026-01-08 17:05:09,447 - INFO - Imported: transcription_aprem_02.txt
# 2026-01-08 17:05:09,455 - INFO - Imported: transcription_matin_02.txt
# 2026-01-08 17:05:09,468 - INFO - Imported: transcription_matin_01.txt
# 2026-01-08 17:05:09,476 - INFO - Imported: transcription_aprem_04.txt
# 2026-01-08 17:05:09,495 - INFO - Imported: transcription_matin_3.txt

# %%
service = TranscriptionService()
service.run()
# Out:
# 2026-01-02 22:39:33,195 - INFO - Found 2 files to process.
# 2026-01-02 22:39:33,196 - INFO - 🚀 Starting pipeline for: matin_01
# 2026-01-02 22:39:33,196 - INFO - Step 1: Extracting audio...
# 2026-01-02 22:39:48,757 - INFO -    -> Audio saved to: data/input/audio/matin_01.wav
# 2026-01-02 22:39:48,758 - INFO - Step 2: Splitting audio...
# 2026-01-02 22:39:49,863 - INFO -    -> Created 3 audio chunks.
# 2026-01-02 22:39:49,864 - INFO - Step 3: Transcribing chunks...
# 2026-01-02 22:39:49,864 - INFO -    -> Transcribing part 1/3...
# 2026-01-02 22:40:06,523 - INFO - HTTP Request: POST https://api.replicate.com/v1/files "HTTP/1.1 201 Created"
# 2026-01-02 22:41:06,843 - INFO - HTTP Request: POST https://api.replicate.com/v1/predictions "HTTP/1.1 202 Accepted"
# 2026-01-02 22:41:07,044 - INFO - HTTP Request: GET https://api.replicate.com/v1/models/victor-upmeet/whisperx/versions/84d2ad2d6194fe98a17d2b60bef1c7f910c46b2f6fd38996ca457afd9c8abfcb "HTTP/1.1 200 OK"
# ...
